# %%
using FastAI

# %%
data, blocks = loaddataset("imagenette2-160", (Image, Label))
method = ImageClassificationSingle(blocks)
learner = methodlearner(method, data, callbacks=[ToGPU()])
fitonecycle!(learner, 10)
showoutputs(method, learner)
# Out:
# ┌ Warning: The NVIDIA driver on this system only supports up to CUDA 11.1.0.
# │ For performance reasons, it is recommended to upgrade to a driver that supports CUDA 11.2 or higher.
# └ @ CUDA C:\Users\amans\.julia\packages\CUDA\Axzxe\src\initialization.jl:70
#  Downloading artifact: CUDA
#  Downloading artifact: CUDNN
# Epoch 1 TrainingPhase(): 100%|██████████████████████████| Time: 0:09:37m
# Epoch 1 ValidationPhase(): 100%|████████████████████████| Time: 0:01:24
# Epoch 2 TrainingPhase(): 100%|██████████████████████████| Time: 0:05:58
# Epoch 2 ValidationPhase(): 100%|████████████████████████| Time: 0:01:06
# Epoch 3 TrainingPhase(): 100%|██████████████████████████| Time: 0:06:00
# Epoch 3 ValidationPhase(): 100%|████████████████████████| Time: 0:01:04
# Epoch 4 TrainingPhase(): 100%|██████████████████████████| Time: 0:05:46
# Epoch 4 ValidationPhase(): 100%|████████████████████████| Time: 0:01:03
# Epoch 5 TrainingPhase(): 100%|██████████████████████████| Time: 0:05:51
# Epoch 5 ValidationPhase(): 100%|████████████████████████| Time: 0:01:07
# Epoch 6 TrainingPhase(): 100%|██████████████████████████| Time: 0:05:44
# Epoch 6 ValidationPhase(): 100%|████████████████████████| Time: 0:01:02
# Epoch 7 TrainingPhase(): 100%|██████████████████████████| Time: 0:06:47
# Epoch 7 ValidationPhase(): 100%|████████████████████████| Time: 0:01:16
# Epoch 8 TrainingPhase(): 100%|██████████████████████████| Time: 0:06:38
# Epoch 8 ValidationPhase(): 100%|████████████████████████| Time: 0:01:04
# Epoch 9 TrainingPhase(): 100%|██████████████████████████| Time: 0:05:42
# Epoch 9 ValidationPhase(): 100%|████████████████████████| Time: 0:01:03
# Epoch 10 TrainingPhase(): 100%|█████████████████████████| Time: 0:05:45
# Epoch 10 ValidationPhase(): 100%|███████████████████████| Time: 0:01:04
# ┌───────────────┬───────┬─────────┐
# │         Phase │ Epoch │    Loss │
# ├───────────────┼───────┼─────────┤
# │ TrainingPhase │   1.0 │ 2.08491 │
# └───────────────┴───────┴─────────┘
# ┌─────────────────┬───────┬─────────┐
# │           Phase │ Epoch │    Loss │
# ├─────────────────┼───────┼─────────┤
# │ ValidationPhase │   1.0 │ 1.81132 │
# └─────────────────┴───────┴─────────┘
# ┌───────────────┬───────┬─────────┐
# │         Phase │ Epoch │    Loss │
# ├───────────────┼───────┼─────────┤
# │ TrainingPhase │   2.0 │ 2.18925 │
# └───────────────┴───────┴─────────┘
# ┌─────────────────┬───────┬─────────┐
# │           Phase │ Epoch │    Loss │
# ├─────────────────┼───────┼─────────┤
# │ ValidationPhase │   2.0 │ 186.768 │
# └─────────────────┴───────┴─────────┘
# ┌───────────────┬───────┬─────────┐
# │         Phase │ Epoch │    Loss │
# ├───────────────┼───────┼─────────┤
# │ TrainingPhase │   3.0 │ 2.82149 │
# └───────────────┴───────┴─────────┘
# ┌─────────────────┬───────┬────────┐
# │           Phase │ Epoch │   Loss │
# ├─────────────────┼───────┼────────┤
# │ ValidationPhase │   3.0 │ 24.659 │
# └─────────────────┴───────┴────────┘
# ┌───────────────┬───────┬─────────┐
# │         Phase │ Epoch │    Loss │
# ├───────────────┼───────┼─────────┤
# │ TrainingPhase │   4.0 │ 2.42545 │
# └───────────────┴───────┴─────────┘
# ┌─────────────────┬───────┬─────────┐
# │           Phase │ Epoch │    Loss │
# ├─────────────────┼───────┼─────────┤
# │ ValidationPhase │   4.0 │ 10.4386 │
# └─────────────────┴───────┴─────────┘
# ┌───────────────┬───────┬─────────┐
# │         Phase │ Epoch │    Loss │
# ├───────────────┼───────┼─────────┤
# │ TrainingPhase │   5.0 │ 2.35901 │
# └───────────────┴───────┴─────────┘
# ┌─────────────────┬───────┬─────────┐
# │           Phase │ Epoch │    Loss │
# ├─────────────────┼───────┼─────────┤
# │ ValidationPhase │   5.0 │ 2550.14 │
# └─────────────────┴───────┴─────────┘
# ┌───────────────┬───────┬─────────┐
# │         Phase │ Epoch │    Loss │
# ├───────────────┼───────┼─────────┤
# │ TrainingPhase │   6.0 │ 2.32251 │
# └───────────────┴───────┴─────────┘
# ┌─────────────────┬───────┬─────────┐
# │           Phase │ Epoch │    Loss │
# ├─────────────────┼───────┼─────────┤
# │ ValidationPhase │   6.0 │ 2.52308 │
# └─────────────────┴───────┴─────────┘
# ┌───────────────┬───────┬─────────┐
# │         Phase │ Epoch │    Loss │
# ├───────────────┼───────┼─────────┤
# │ TrainingPhase │   7.0 │ 2.06702 │
# └───────────────┴───────┴─────────┘
# ┌─────────────────┬───────┬─────────┐
# │           Phase │ Epoch │    Loss │
# ├─────────────────┼───────┼─────────┤
# │ ValidationPhase │   7.0 │ 2.96825 │
# └─────────────────┴───────┴─────────┘
# ┌───────────────┬───────┬─────────┐
# │         Phase │ Epoch │    Loss │
# ├───────────────┼───────┼─────────┤
# │ TrainingPhase │   8.0 │ 1.91674 │
# └───────────────┴───────┴─────────┘
# ┌─────────────────┬───────┬─────────┐
# │           Phase │ Epoch │    Loss │
# ├─────────────────┼───────┼─────────┤
# │ ValidationPhase │   8.0 │ 3.10914 │
# └─────────────────┴───────┴─────────┘
# ┌───────────────┬───────┬─────────┐
# │         Phase │ Epoch │    Loss │
# ├───────────────┼───────┼─────────┤
# │ TrainingPhase │   9.0 │ 1.79859 │
# └───────────────┴───────┴─────────┘
# ┌─────────────────┬───────┬─────────┐
# │           Phase │ Epoch │    Loss │
# ├─────────────────┼───────┼─────────┤
# │ ValidationPhase │   9.0 │ 2.18479 │
# └─────────────────┴───────┴─────────┘
# ┌───────────────┬───────┬─────────┐
# │         Phase │ Epoch │    Loss │
# ├───────────────┼───────┼─────────┤
# │ TrainingPhase │  10.0 │ 1.73647 │
# └───────────────┴───────┴─────────┘
# ┌─────────────────┬───────┬─────────┐
# │           Phase │ Epoch │    Loss │
# ├─────────────────┼───────┼─────────┤
# │ ValidationPhase │  10.0 │ 2.42708 │
# └─────────────────┴───────┴─────────┘
# KeyError: key :nothing not found
#
# Stacktrace:
#   [1] getindex(h::Dict{Symbol, Int64}, key::Symbol)
#     @ Base .\dict.jl:481
#   [2] _parse_color
#     @ C:\Users\amans\.julia\packages\Crayons\u3AH8\src\crayon.jl:143 [inlined]
#   [3] #Crayon#1
#     @ C:\Users\amans\.julia\packages\Crayons\u3AH8\src\crayon.jl:171 [inlined]
#   [4] encodeimg(::ImageInTerminal.SmallBlocks, colordepth::ImageInTerminal.TermColor256, img::Matrix{ColorTypes.RGB{Float32}}, maxheight::Int64, maxwidth::Int64)
#     @ ImageInTerminal C:\Users\amans\.julia\packages\ImageInTerminal\aJGpm\src\encodeimg.jl:65
#   [5] imshow(io::IOContext{IOBuffer}, img::Matrix{ColorTypes.RGB{Float32}}, colordepth::ImageInTerminal.TermColor256, maxsize::Tuple{Int64, Int64})
#     @ ImageInTerminal C:\Users\amans\.julia\packages\ImageInTerminal\aJGpm\src\imshow.jl:31
#   [6] imshow(io::IOContext{IOBuffer}, img::Matrix{ColorTypes.RGB{Float32}}, colordepth::ImageInTerminal.TermColor256)
#     @ ImageInTerminal C:\Users\amans\.julia\packages\ImageInTerminal\aJGpm\src\imshow.jl:26
#   [7] imshow(::IOContext{IOBuffer}, ::Matrix{ColorTypes.RGB{Float32}})
#     @ ImageInTerminal C:\Users\amans\.julia\packages\ImageInTerminal\aJGpm\src\imshow.jl:58
#   [8] showblock!
#     @ C:\Users\amans\.julia\packages\FastAI\jkmYS\src\interpretation\text.jl:62 [inlined]
#   [9] showblock!
#     @ C:\Users\amans\.julia\packages\FastAI\jkmYS\src\interpretation\backend.jl:117 [inlined]
#  [10] #160
#     @ C:\Users\amans\.julia\packages\FastAI\jkmYS\src\interpretation\text.jl:33 [inlined]
#  [11] PrettyTables.AnsiTextCell(renderfn::FastAI.var"#160#164"{FastAI.Bounded{2, Image{2}}, Matrix{ColorTypes.RGB{Float32}}, ShowText}; context::Tuple{})
#     @ PrettyTables C:\Users\amans\.julia\packages\PrettyTables\nQZHQ\src\backends\text\custom_text_cells\ansi_text_cell.jl:159
#  [12] PrettyTables.AnsiTextCell(renderfn::Function)
#     @ PrettyTables C:\Users\amans\.julia\packages\PrettyTables\nQZHQ\src\backends\text\custom_text_cells\ansi_text_cell.jl:158
#  [13] #159
#     @ .\none:0 [inlined]
#  [14] iterate
#     @ .\generator.jl:47 [inlined]
#  [15] collect(itr::Base.Generator{Base.Iterators.Zip{Tuple{Vector{FastAI.AbstractBlock}, Tuple{Matrix{ColorTypes.RGB{Float32}}, SubArray{Float32, 1, Matrix{Float32}, Tuple{Base.Slice{Base.OneTo{Int64}}, Int64}, true}}}}, FastAI.var"#159#163"{ShowText}})
#     @ Base .\array.jl:724
#  [16] showblock!(io::IOContext{IOBuffer}, backend::ShowText, blocks::Tuple{FastAI.Bounded{2, Image{2}}, FastAI.OneHotTensor{0, String}}, datas::Tuple{Matrix{ColorTypes.RGB{Float32}}, SubArray{Float32, 1, Matrix{Float32}, Tuple{Base.Slice{Base.OneTo{Int64}}, Int64}, true}})
#     @ FastAI C:\Users\amans\.julia\packages\FastAI\jkmYS\src\interpretation\text.jl:33
